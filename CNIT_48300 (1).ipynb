# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, optimizers
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential

import matplotlib
import pathlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from tensorflow.keras.preprocessing.image import ImageDataGenerator


# !pip install bing-image-downloader

import os
import shutil
from bing_image_downloader import downloader

directory_list = [
    './custom_dataset/train/',
    './custom_dataset/test/',
]

train_path="./custom_dataset/train/"
test_path="./custom_dataset/test/"

# %%
for directory in directory_list:
    if not os.path.isdir(directory):
        os.makedirs(directory)


def dataset_split(query, train_cnt):
 
    for directory in directory_list:
        if not os.path.isdir(directory + '/' + query):
            os.makedirs(directory + '/' + query)
 
    cnt = 0
    for file_name in os.listdir(query):
        if cnt < train_cnt:
            print(f'[Train Dataset] {file_name}')
            shutil.move(query + '/' + file_name, './custom_dataset/train/' + query + '/' + file_name)
        else:
            print(f'[Test Dataset] {file_name}')
            shutil.move(query + '/' + file_name, './custom_dataset/test/' + query + '/' + file_name)
        cnt += 1
    shutil.rmtree(query)

# %%
query = 'Angelina Jolie'
downloader.download(query, limit=50, output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query,40)
# Out:
# [%] Downloading Images to /content/Angelina Jolie
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 50 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.hawtcelebs.com/wp-content/uploads/2018/01/angelina-jolie-at-75th-annual-golden-globe-awards-in-beverly-hills-01-07-2018-4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.hawtcelebs.com/wp-content/uploads/2019/10/angelina-jolie-at-maleficent-mistress-of-evil-premiere-in-tokyo-10-03-2019-6.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://akns-images.eonline.com/eol_images/Entire_Site/2019519/rs_634x1024-190619104358-634x1024-angelinajolie-gj-6-19-19.jpg?fit=around|634:1024&amp;output-quality=90&amp;crop=634:1024;center,top
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.hawtcelebs.com/wp-content/uploads/2014/03/angelina-jolie-at-86th-annual-academy-awards-in-hollywood_16.jpg
# [%] File Downloaded !
#
# ...

# %%
query = 'Barack Obama'
downloader.download(query, limit=50, output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query,40)
# Out:
# [%] Downloading Images to /content/Barack Obama
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 50 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://external-preview.redd.it/Z_cIAGrGy4wQKUTVwD6jBkD8I_fvG_fSTiroi_4eIKM.jpg?auto=webp&amp;s=16f41704f4926e2233bd2514275601b1db049696
# [!] Issue getting: https://external-preview.redd.it/Z_cIAGrGy4wQKUTVwD6jBkD8I_fvG_fSTiroi_4eIKM.jpg?auto=webp&amp;s=16f41704f4926e2233bd2514275601b1db049696
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #1 from https://media.vanityfair.com/photos/5eb6e24a77a607fc7f7f1572/master/w_2560%2Cc_limit/Barack-Obama.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://external-preview.redd.it/s6kXPoK7hb_fLBtjW94tu64_F3pBctQhtwMJCAcsIHE.jpg?auto=webp&amp;s=e24a348ba590f6711c2be70fe0adc25f117db7bc
# [!] Issue getting: https://external-preview.redd.it/s6kXPoK7hb_fLBtjW94tu64_F3pBctQhtwMJCAcsIHE.jpg?auto=webp&amp;s=e24a348ba590f6711c2be70fe0adc25f117db7bc
# ...

# %%
query = 'Lionel Messi'
downloader.download(query, limit=50, output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query,40)
# Out:
# [%] Downloading Images to /content/Lionel Messi
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 50 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i0.wp.com/sportytell.com/wp-content/uploads/2018/12/Lionel-Messi-of-FC-Barcelona.jpg?fit=1920%2C1080&amp;ssl=1
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://media.spokesman.com/photos/2019/07/23/Copa_America_Argentina_Qatar.JPG.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://articleify.com/wp-content/uploads/2020/09/Messi.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://mundoalbiceleste.com/wp-content/uploads/2019/03/IMG_20190309_231330.jpg
# [!] Issue getting: https://mundoalbiceleste.com/wp-content/uploads/2019/03/IMG_20190309_231330.jpg
# [!] Error:: <urlopen error [Errno -3] Temporary failure in name resolution>
# [%] Downloading Image #4 from https://blog.confirmbets.com/wp-content/uploads/2019/07/Messi.jpg
# [%] File Downloaded !
#
# ...

# %%
query = 'Yuna Kim'
downloader.download(query, limit=50, output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query,40)
# Out:
# [%] Downloading Images to /content/Yuna Kim
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 50 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://s.yimg.com/uu/api/res/1.2/AfMDSK.nTG0oznpqhfBf_w--~B/aD0yMDAwO3c9MTY3OTtzbT0xO2FwcGlkPXl0YWNoeW9u/http://media.zenfs.com/en_us/News/ap_webfeeds/38ee2203a07afa064b0f6a7067004bc6.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/a5/a5/ad/a5a5ad3fe7d06a72b3f2af078b66a62a.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://ilarge.lisimg.com/image/12003701/1118full-yuna-kim.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://celebmafia.com/wp-content/uploads/2019/03/yuna-kim-photoshoot-for-new-balance-s-s-2019-3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://cdn1.i-scmp.com/sites/default/files/styles/768x768/public/images/methode/2018/02/22/d871fe14-16ca-11e8-ace5-29063da208e4_1280x720_145815.jpg?itok=pRZdEqhS
# [%] File Downloaded !
#
# ...

# %%
rm -rf `find -type d -name .ipynb_checkpoints`

# %%
import matplotlib.image as mpimg
import random

def view_random_image(target_dir, target_class):
  target_folder = target_dir+target_class

  random_image = random.sample(os.listdir(target_folder), 1)

  img = mpimg.imread(target_folder + "/" + random_image[0])
  plt.imshow(img)
  plt.title(target_class)
  plt.axis("off");

  print(f"Image shape: {img.shape}") 

  return img

# %%
img = view_random_image(target_dir="./custom_dataset/train/",
                        target_class="Angelina Jolie")
# Out:
# Image shape: (1079, 720, 3)

# %%
img = view_random_image(target_dir="./custom_dataset/train/",
                        target_class="Barack Obama")
# Out:
# Image shape: (2900, 4488, 3)

# %%
import pathlib
import numpy as np
data_dir = pathlib.Path(train_path)
class_names = np.array(sorted([item.name for item in data_dir.glob('*')]))
print(class_names)
# Out:
# ['Angelina Jolie' 'Barack Obama' 'Lionel Messi' 'Yuna Kim']

# %%
training_datagen = ImageDataGenerator(rescale=1/255.)
test_datagen = ImageDataGenerator(rescale=1/255.)

training_set = training_datagen.flow_from_directory(train_path,
                                                          target_size=(224, 224),
                                                          batch_size=32,
                                                          class_mode='categorical',
                                                          shuffle = True)
                                                
test_set = test_datagen.flow_from_directory(test_path,
                                            target_size = (224, 224),
                                            batch_size = 32,
                                            class_mode = 'categorical',
                                            shuffle = True)
# Out:
# Found 160 images belonging to 4 classes.
# Found 40 images belonging to 4 classes.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, BatchNormalization

model = Sequential([
  Conv2D(1, 3, activation='relu', input_shape=(224, 224, 3)),
  MaxPool2D(pool_size=2),
  Conv2D(2, 3, activation='relu'),
  layers.Dropout(0.4),
  MaxPool2D(),
  Conv2D(4, 3, activation='relu'),
  layers.Dropout(0.4),
  MaxPool2D(),
  layers.Dropout(0.4),
  Flatten(),
  Dense(4, activation='softmax')
])

# Compile the model
model.compile(loss="categorical_crossentropy", 
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"])

history = model.fit(training_set, 
                        epochs=30,
                        steps_per_epoch=len(training_set),
                        validation_data=test_set,
                        validation_steps=len(test_set))
# Out:
# Epoch 1/30
# 5/5 [==============================] - 17s 3s/step - loss: 1.4293 - accuracy: 0.2188 - val_loss: 1.3779 - val_accuracy: 0.2750
# Epoch 2/30
# 5/5 [==============================] - 13s 2s/step - loss: 1.3609 - accuracy: 0.3125 - val_loss: 1.3703 - val_accuracy: 0.3000
# Epoch 3/30
# 5/5 [==============================] - 13s 3s/step - loss: 1.3228 - accuracy: 0.3875 - val_loss: 1.3601 - val_accuracy: 0.3750
# Epoch 4/30
# 5/5 [==============================] - 13s 3s/step - loss: 1.2794 - accuracy: 0.4000 - val_loss: 1.3460 - val_accuracy: 0.5000
# Epoch 5/30
# 5/5 [==============================] - 13s 3s/step - loss: 1.2422 - accuracy: 0.4688 - val_loss: 1.3266 - val_accuracy: 0.5500
# Epoch 6/30
# 5/5 [==============================] - 13s 2s/step - loss: 1.1732 - accuracy: 0.5125 - val_loss: 1.3015 - val_accuracy: 0.5250
# Epoch 7/30
# 5/5 [==============================] - 13s 3s/step - loss: 1.0952 - accuracy: 0.5500 - val_loss: 1.2713 - val_accuracy: 0.5000
# ...

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_9 (Conv2D)           (None, 222, 222, 1)       28
#
#  max_pooling2d_8 (MaxPooling  (None, 111, 111, 1)      0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 109, 109, 2)       20
#
#  dropout_9 (Dropout)         (None, 109, 109, 2)       0
#
#  max_pooling2d_9 (MaxPooling  (None, 54, 54, 2)        0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 52, 52, 4)         76
#
#  dropout_10 (Dropout)        (None, 52, 52, 4)         0
#
#  max_pooling2d_10 (MaxPoolin  (None, 26, 26, 4)        0
#  g2D)
#
#  dropout_11 (Dropout)        (None, 26, 26, 4)         0
#
#  flatten_3 (Flatten)         (None, 2704)              0
#
#  dense_3 (Dense)             (None, 4)                 10820
#
# ...
# Total params: 10,944
# Trainable params: 10,944
# Non-trainable params: 0
# ...

# %%
model.evaluate(test_set)
# Out:
# 2/2 [==============================] - 3s 715ms/step - loss: 0.9484 - accuracy: 0.6250
# [0.9483726620674133, 0.625]

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
angelina = mpimg.imread("./sample_data/angelina.jpeg")
plt.imshow(angelina)
plt.axis(False);

angelina.shape

def load_and_prep_image(filename, img_shape=224):
 
  img = tf.io.read_file(filename)
 
  img = tf.image.decode_image(img, channels=3)

  img = tf.image.resize(img, size = [img_shape, img_shape])

  img = img/255.
  return img

angelina = load_and_prep_image("./sample_data/angelina.jpeg")
angelina
# Out:
# <tf.Tensor: shape=(224, 224, 3), dtype=float32, numpy=
# array([[[0.83752626, 0.9081145 , 0.9473302 ],
#         [0.74150467, 0.8120929 , 0.8513086 ],
#         [0.7529412 , 0.8235294 , 0.8627451 ],
#         ...,
#         [0.8980392 , 0.8980392 , 0.8980392 ],
#         [0.8943972 , 0.8943972 , 0.8943972 ],
#         [0.8901961 , 0.8901961 , 0.8901961 ]],
#
#        [[0.75442487, 0.8250131 , 0.8777092 ],
#         [0.759712  , 0.8303003 , 0.8829963 ],
#         [0.7529412 , 0.8235294 , 0.8762255 ],
#         ...,
#         [0.8980392 , 0.8980392 , 0.8980392 ],
#         [0.8943972 , 0.8943972 , 0.8943972 ],
#         [0.8901961 , 0.8901961 , 0.8901961 ]],
#
#        [[0.7484069 , 0.81507355, 0.87781864],
#         [0.7500394 , 0.81670606, 0.87945116],
#         [0.7529412 , 0.81960785, 0.88235295],
#         ...,
#         [0.8980392 , 0.8980392 , 0.8980392 ],
#         [0.8943972 , 0.8943972 , 0.8943972 ],
#         [0.8901961 , 0.8901961 , 0.8901961 ]],
#
#        ...,
#
# ...

# %%
print(f"Shape before new dimension: {angelina.shape}")
angelina = tf.expand_dims(angelina, axis=0) 
print(f"Shape after new dimension: {angelina.shape}")
angelina
# Out:
# Shape before new dimension: (224, 224, 3)
# Shape after new dimension: (1, 224, 224, 3)
# <tf.Tensor: shape=(1, 224, 224, 3), dtype=float32, numpy=
# array([[[[0.83752626, 0.9081145 , 0.9473302 ],
#          [0.74150467, 0.8120929 , 0.8513086 ],
#          [0.7529412 , 0.8235294 , 0.8627451 ],
#          ...,
#          [0.8980392 , 0.8980392 , 0.8980392 ],
#          [0.8943972 , 0.8943972 , 0.8943972 ],
#          [0.8901961 , 0.8901961 , 0.8901961 ]],
#
#         [[0.75442487, 0.8250131 , 0.8777092 ],
#          [0.759712  , 0.8303003 , 0.8829963 ],
#          [0.7529412 , 0.8235294 , 0.8762255 ],
#          ...,
#          [0.8980392 , 0.8980392 , 0.8980392 ],
#          [0.8943972 , 0.8943972 , 0.8943972 ],
#          [0.8901961 , 0.8901961 , 0.8901961 ]],
#
#         [[0.7484069 , 0.81507355, 0.87781864],
#          [0.7500394 , 0.81670606, 0.87945116],
#          [0.7529412 , 0.81960785, 0.88235295],
#          ...,
#          [0.8980392 , 0.8980392 , 0.8980392 ],
# ...

# %%
pred = model.predict(angelina)
pred
pred_class = class_names[int(tf.round(pred)[0][0])]
pred_class
# Out:
# 'Angelina Jolie'

# %%
def pred_and_plot(model, filename, class_names):

   img = load_and_prep_image(filename)

   pred = model.predict(tf.expand_dims(img, axis=0))
   
   if len(pred[0]) > 1: 
    pred_class = class_names[pred.argmax()] 
   else:
    pred_class = class_names[int(tf.round(pred)[0][0])]

   plt.imshow(img)
   plt.title(f"Prediction: {pred_class}")
   plt.axis(False);

# %%
pred_and_plot(model,"./sample_data/yuna.jpeg", class_names)

# %%
pred_and_plot(model,"./sample_data/angelina3.jpeg", class_names)

# %%
pred_and_plot(model,"./sample_data/obama.jpeg", class_names)
